# %% [markdown]
# # 08 — Bond Cash Flows, Price and Yield

# %% [markdown]
# ## Free learning pack
# 1. PIMCO Fixed Income Education Center
#    https://www.pimco.com/ca/en/resources/education-center/fixed-income
# 2. PIMCO Understanding Duration
#    https://www.pimco.com/us/en/resources/education/understanding-duration
# 3. MIT Finance Theory I fixed-income materials
#    https://ocw.mit.edu/courses/15-401-finance-theory-i-fall-2008/
# 4. `resources/fixed_income.md`

# %% [markdown]
# ## Vocabulary
# par, coupon, maturity, clean price, dirty price, accrued interest, YTM, premium, discount

# %% [markdown]
# ## HAND CALCULATION
# Price a 2-year annual-pay 5% coupon, $100 face bond at a 4% yield.
#
# `P = 5/1.04 + 105/(1.04)^2`

# %%
# MANUAL FIRST
def my_bond_price(ytm, face=100, coupon_rate=.05, years=2, frequency=1):
    # type discounted cash-flow logic yourself
    raise NotImplementedError

# %% [markdown]
# ## Then compare
# `src/pm/fixed_income/bond.py`
#
# ## ORAL CHECK
# Why does a fixed-rate bond trade above par when coupon > yield?
