# %% [markdown]
# # 06 — Benchmark-Relative Portfolio Management

# %% [markdown]
# ## Free learning pack
# 1. CFA Analysis of Active Portfolio Management
#    https://www.cfainstitute.org/insights/professional-learning/refresher-readings/2026/analysis-active-portfolio-management
# 2. `resources/active_management.md`
# 3. `reference/concepts/tracking_error.md`

# %% [markdown]
# ## Formula
# `a = w_p - w_b`
# `TE = sqrt(a^T Sigma a)`

# %%
import numpy as np

portfolio = np.array([.30,.25,.25,.20])
benchmark = np.array([.25,.25,.30,.20])
cov = np.diag([.04,.02,.01,.03])

# MANUAL FIRST:
# active weights
# tracking error

# %% [markdown]
# ## Questions
# - Where is conviction being expressed?
# - Can total volatility fall while tracking error rises?
# - Why?
#
# ## Reference
# `reference/concepts/tracking_error.md`
