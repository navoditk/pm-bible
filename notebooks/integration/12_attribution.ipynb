# %% [markdown]
# # 12 — Attribution and Capstone

# %% [markdown]
# ## Free learning pack
# Review your own notes plus:
# 1. CFA active portfolio management page
# 2. PIMCO fixed-income education hub
# 3. relevant `reference/` pages

# %% [markdown]
# ## Distinction
# Attribution asks: **what caused realized performance?**
#
# Start with a teaching decomposition:
# - carry
# - rates
# - curve
# - spread
# - equity/factor
# - residual/selection

# %%
contributions = {
    "carry": 210_000,
    "rates": 470_000,
    "curve": -80_000,
    "credit_spread": 510_000,
    "selection_residual": 230_000,
}

# MANUAL FIRST: reconcile total P&L.

# %% [markdown]
# ## Capstone questions
# 1. What is driving risk?
# 2. How much risk is active vs total?
# 3. What is the portfolio's duration/DV01?
# 4. Where is curve risk?
# 5. What happens in a risk-off scenario?
# 6. What constraints matter in optimization?
# 7. How would you explain the output to a PM?
#
# ## End
# Update `docs/PROGRESS.md`.
